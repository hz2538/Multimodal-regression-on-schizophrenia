# %% [markdown]
# # SVR

# %%
import scipy.io as sio
import pandas as pd
from tqdm import tnrange, tqdm_notebook
from sklearn.preprocessing import maxabs_scale, minmax_scale, scale
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
import warnings
from sklearn.svm import SVR
from sklearn.model_selection import KFold
from sklearn.feature_selection import RFE
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.metrics.pairwise import linear_kernel, rbf_kernel
import itertools
import math
warnings.filterwarnings('ignore')
sns.set(style='whitegrid',palette='cividis')

# %%
# rdata_raw = sio.loadmat('D:/ML/data/Data_noV0/rData.mat')['rData_all'].T
# cdata_raw = sio.loadmat('D:/ML/data/Data_noV0/cData.mat')['cData_all'].T
# xdata_raw = sio.loadmat('D:/ML/data/Data_noV0/xData.mat')['xData_all'].T
# pdata_raw = sio.loadmat('D:/ML/data/Data_noV0/pData.mat')['pData_all'].T
# # data_raw = np.hstack((rdata_raw,cdata_raw,xdata_raw,pdata_raw))
# weight = [15,14,14,14,14,14,14,14,14,14] # 10-fold validation proportion

# pos = sio.loadmat('D:/ML/data/Data_noV0/posPANSS.mat')['pos_all'].T
# neg = sio.loadmat('D:/ML/data/Data_noV0/negPANSS.mat')['neg_all'].T
# gen = sio.loadmat('D:/ML/data/Data_noV0/genPANSS.mat')['gen_all'].T
# tot = sio.loadmat('D:/ML/data/Data_noV0/totPANSS.mat')['tot_all'].T
# cog = sio.loadmat('D:/ML/data/Data_noV0/cogPANSS.mat')['PANSS_cog_all'].T

# No V0
rdata_raw = sio.loadmat('Data_noV0/rData.mat')['rData_all'].T
cdata_raw = sio.loadmat('Data_noV0/cData.mat')['cData_all'].T
xdata_raw = sio.loadmat('Data_noV0/xData.mat')['xData_all'].T
pdata_raw = sio.loadmat('Data_noV0/pData.mat')['pData_all'].T
cog = sio.loadmat('Data_noV0/cogPANSS.mat')['PANSS_cog_all'].T
tot = sio.loadmat('Data_noV0/totPANSS.mat')['tot_all'].T

# %%
# Normalization
rdata_maxabs = maxabs_scale(rdata_raw,axis=0)
cdata_maxabs = maxabs_scale(cdata_raw,axis=0)
pdata_maxabs = maxabs_scale(pdata_raw,axis=0)
xdata_maxabs = maxabs_scale(xdata_raw,axis=0)
data_maxabs = [rdata_maxabs,cdata_maxabs,xdata_maxabs,pdata_maxabs]

# %%
# Normalization
rdata_minmax = minmax_scale(rdata_raw,axis=0,feature_range=(-1,1))
cdata_minmax = minmax_scale(cdata_raw,axis=0,feature_range=(-1,1))
pdata_minmax = minmax_scale(pdata_raw,axis=0,feature_range=(-1,1))
xdata_minmax = minmax_scale(xdata_raw,axis=0,feature_range=(-1,1))
data_minmax = [rdata_minmax,cdata_minmax,xdata_minmax,pdata_minmax]

# %%
# score normalization
cog_app = np.vstack((cog,[10],[52]))
# score = np.hstack((pos,neg,gen,tot))
cog_minmax = minmax_scale(cog_app,axis=0)
cog_maxabs = maxabs_scale(cog_app,axis=0)
cog_norm = cog_minmax[:-2]

# %%
# score normalization
tot_app = np.vstack((tot,[30],[170]))
# score = np.hstack((pos,neg,gen,tot))
tot_minmax = minmax_scale(cog_app,axis=0)
tot_maxabs = maxabs_scale(cog_app,axis=0)
tot_norm = tot_minmax[:-2]

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.distplot(cog_norm)

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.distplot(tot_norm)

# %%
def lassoWriter(path, feature, result, score, best_r2, state):
    f = open(path, 'a')
    f.write('========================================\n')
    f.write('=====Exp:'+str(datetime.now())+'=====\n')
    f.write('========================================\n')
    f.write('Kernel: Linear, State: '+str(state)+'\n')
    f.write('Best R2: '+str(round(best_r2[1],8))+'\n')
    f.write('at Alpha: '+str(round(best_r2[0],7)))
    f.write('\n----------------------------------------\n')
    f.write('Selected Features '+str(len(feature))+':\n')
    for i in range(int(len(feature)/25)):
        for j in range(25):
            f.write(str(feature[i*25+j])+',')
        f.write('\n')
    for i in range(len(feature)%25):
        f.write(str(feature[i-len(feature)%25])+',')
    f.write('\n----------------------------------------\n')
    f.write('Predict and Truth at Best Alpha and Fold:\n')
    for item in result[0]:
        f.write(str(round(item,2))+',')
    f.write('\n')
    for item in result[1]:
        f.write(str(item)+'.00,')
    f.write('\n----------------------------------------\n')
    f.write('MSE and R2 at Best Alpha:\n')
    for item in score[0]:
        f.write(str(round(item,5))+',')
    f.write('\n')
    for item in score[1]:
        f.write(str(round(item,5))+',')
    f.write('\n-----------------END--------------------\n\n\n')

# %%
def cal_score(data,data_max,data_min):
    return np.dot(data,(data_max - data_min)) + data_min

# %%
def create_alpha(ll,ul,step):
    ilist=[]
    ilist_exp = np.linspace(ll,ul,step)
    ilist_raw = [[10**(item),5.0*10**(item)] for item in ilist_exp]
    [ilist.extend(i) for i in ilist_raw]
    return ilist

# %% [markdown]
# ## Single kernel Lasso

# %%
def lassoCD(X, y, ll, ul, step, state, score_min, score_max):
    kf = KFold(n_splits=10,shuffle=True,random_state=state)
    feature = []
    score = []
    metric = []
    m_mse = []
    m_r2 = []
    ilist = np.linspace(ll,ul,step)
    pbar = tnrange(step*10, desc='loop')
    for i in ilist: # search best parameter
        mse = []
        r2 = []
        fea = []
        sco_pred = []
        sco_true = []
        for train_index, test_index in kf.split(X):
            y_train, y_test_raw = y[train_index], y[test_index]
            X_train_tmp, X_test_tmp = X[train_index], X[test_index]
            
            clf = Lasso(alpha=i)
            clf.fit(X_train_tmp, np.ravel(y_train))
            fea_idx = [i for i,x in enumerate(clf.coef_) if x>0]
            X_train = X_train_tmp[:,fea_idx]
            X_test = X_test_tmp[:,fea_idx]
            y_test_raw = list(list(zip(*y_test_raw))[0])

#             svr = SVR(kernel='poly',gamma=0.5, degree=5, epsilon=0.1, C=100)
            svr = SVR(kernel='rbf',gamma=0.5, epsilon=0.1, C=1)
#             svr = SVR(kernel='linear', epsilon=0.1, C=100)
#             svr = SVR(kernel='rbf',gamma=1.0, epsilon=0.1)
#             svr = SVR(kernel='rbf',gamma=0.45, epsilon=0.1)
            
            svr.fit(X_train, np.ravel(y_train))
            y_test_pred_raw = svr.predict(X_test)
            y_test_pred = cal_score(y_test_pred_raw,score_max,score_min)
            y_test = cal_score(y_test_raw,score_max,score_min)
            mse.append(mean_squared_error(y_test, y_test_pred))
            r2.append(r2_score(y_test, y_test_pred))
            fea.append(fea_idx)
            sco_pred.append(list(y_test_pred))
            sco_true.append(list(y_test))
            pbar.update(1)
        feature.append(fea)
        score.append((sco_pred, sco_true))
        metric.append((mse,r2))
        m_mse.append(sum(mse)/10)  # mean mse trace for all alpha
        m_r2.append(sum(r2)/10)    # mean r2 trace for all alpha
    
    a = m_r2.index(max(m_r2))
    feature_fd = [len(feature[a][i]) for i in range(10)]
    num_feature = int(np.mean(feature_fd))
    df = {'max_r2': m_r2[a], 'best_alpha': ilist[a], 'num_features': num_feature}
    pbar.close()
#     plt.figure()
#     plt.plot(ilist,m_r2)
#     plt.xlabel('$alpha$')
#     plt.ylabel('$R^2$')
    print(m_r2)
    print('best r2_score=',m_r2[a],', corresponding alpha=', ilist[a])
    print('number of selected features:',num_feature)
    return df, feature[a], score[a], metric[a]

# %% [markdown]
# ### cdata

# %%
# kernel='rbf',gamma=0.45, epsilon=0.1
X = cdata_minmax
y = cog_norm
ll = 0.0120
ul = 0.0124
step = 9
state = 73
score_min = 10
score_max = 52
result, feature, score, metric = lassoCD(X, y, ll, ul, step, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=90, style=ProgressStyle(description_width='initial…
# [-0.07931608894254027, -0.08702432448086184, -0.0704175663920414, -0.06651505429754812, -0.06651505429754812, -0.06651505429754812, -0.06651505429754812, -0.06651505429754812, -0.07050329764436944]
# best r2_score= -0.06651505429754812 , corresponding alpha= 0.01215
# number of selected features: 3

# %%
# kernel='rbf',gamma=0.45
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.066292
# True     0.066292  1.000000

# %%
# kernel='rbf',gamma=1.0
X = cdata_maxabs
y = cog_norm
ll = 0.00650
ul = 0.00690
step = 41
state = 73
score_min = 10
score_max = 52
result, feature, score, metric = lassoCD(X, y, ll, ul, step, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=410, style=ProgressStyle(description_width='initia…
# [-0.10284593508308833, -0.10284593508308833, -0.10739452830863971, -0.10739452830863971, -0.10073833693501111, -0.10073833693501111, -0.09800239741866694, -0.09800239741866694, -0.09800239741866694, -0.09800239741866694, -0.09338276011204465, -0.09338276011204465, -0.07528954146959485, -0.07528954146959485, -0.07528954146959485, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07958450919689626, -0.07388751018105373, -0.07952875645933835, -0.07952875645933835, -0.07952875645933835, -0.08522021039475046, -0.08522021039475046, -0.08522021039475046, -0.0725866829559437, -0.08084680333994612, -0.08084680333994612]
# best r2_score= -0.0725866829559437 , corresponding alpha= 0.00688
# number of selected features: 4

# %%
# kernel='rbf',gamma=1.0
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.026674
# True     0.026674  1.000000

# %% [markdown]
# ### pdata

# %%
# kernel='rbf',gamma=0.5, epsilon=0.01, C=1
X = pdata_maxabs
y = cog_norm
ll = 0.0085
ul = 0.009
step = 10
state = 73
score_min = 10
score_max = 52
result, feature, score, metric = lassoCD(X, y, ll, ul, step, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', style=ProgressStyle(description_width='initial')), HTM…
# [0.02071388291829377, 0.007232298643291213, -0.0016708483912722173, 0.0007414675598225173, -0.028579234725458737, -0.02754668682898358, -0.03103393418747389, -0.03399256918645521, -0.03081515131021072, -0.03510903875001613]
# best r2_score= 0.02071388291829377 , corresponding alpha= 0.0085
# number of selected features: 23

# %%
# kernel='rbf',gamma=0.5, epsilon=0.1, C=1
X = pdata_maxabs
y = cog_norm
ll = 0.00866
ul = 0.0090
step = 1
state = 73
score_min = 10
score_max = 52
result, feature, score, metric = lassoCD(X, y, ll, ul, step, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=10, style=ProgressStyle(description_width='initial…
# [-0.009613941198800735]
# best r2_score= -0.009613941198800735 , corresponding alpha= 0.00866
# number of selected features: 22

# %%
# kernel='rbf',gamma=0.5, epsilon=0.01, C=1
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.334466
# True     0.334466  1.000000

# %%
# kernel='rbf',gamma=0.5, epsilon=0.1, C=1
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.302198
# True     0.302198  1.000000

# %% [markdown]
# ## Elastic Net

# %%
def elastic_net(X, y, ll1, ul1, step1, ll2, ul2, step2, state, score_min, score_max):
    kf = KFold(n_splits=10,shuffle=True,random_state=state)
    feature = []
    score = []
    metric = []
    m_mse = []
    m_r2 = []
    pbar = tnrange(step1*step2*10, desc='loop')
    inp = [list(np.linspace(ll1,ul1,step1)), list(np.linspace(ll2,ul2,step2))]
    g = [i for i in itertools.product(*inp)]
    ilist = []
    for k in range(len(g)):
        mse = []
        r2 = []
        fea = []
        sco_pred = []
        sco_true = []
        for train_index, test_index in kf.split(X):
            y_train, y_test_raw = y[train_index], y[test_index]
            X_train_tmp, X_test_tmp = X[train_index], X[test_index]
            regr = ElasticNet(random_state=state,alpha=g[k][0],l1_ratio=g[k][1])
            regr.fit(X_train_tmp, np.ravel(y_train))
            fea_idx = [i for i,x in enumerate(regr.coef_) if x>0]
            X_train = X_train_tmp[:,fea_idx]
            X_test = X_test_tmp[:,fea_idx]
            y_test_raw = list(list(zip(*y_test_raw))[0])

#             svr = SVR(kernel='linear')
            svr = SVR(kernel='rbf',gamma=0.5, epsilon=0.1, C=1)
#             svr = SVR(kernel='rbf',gamma=1.0)
#             svr = SVR(kernel='rbf',gamma=0.45, epsilon=0.1)
    
            svr.fit(X_train, np.ravel(y_train))
            y_test_pred_raw = svr.predict(X_test)
            y_test_pred = cal_score(y_test_pred_raw,score_max,score_min)
            y_test = cal_score(y_test_raw,score_max,score_min)
            mse.append(mean_squared_error(y_test, y_test_pred))
            r2.append(r2_score(y_test, y_test_pred))
            fea.append(fea_idx)
            sco_pred.append(list(y_test_pred))
            sco_true.append(list(y_test))
            pbar.update(1)
        feature.append(fea)
        score.append((sco_pred, sco_true))
        metric.append((mse,r2))
        m_mse.append(sum(mse)/10)  # mean mse trace for all alpha
        m_r2.append(sum(r2)/10)    # mean r2 trace for all alpha
        ilist.append(g[k])
    a = m_r2.index(max(m_r2))
    feature_fd = [len(feature[a][i]) for i in range(10)]
    num_feature = int(np.mean(feature_fd))
    df = {'max_r2': m_r2[a], 'best_alpha': ilist[a], 'num_features': num_feature}
    pbar.close()
#     print(m_r2)
#     plt.figure()
#     plt.scatter(np.log10(np.array(g)[:,0]),np.array(g)[:,1],c=m_r2,marker='.',cmap='copper_r')
#     plt.xlabel('$alpha$')
#     plt.ylabel('$L1 ratio$')
#     print(np.array(ilist),m_r2)
#     plt.axis([ll1-(ul1-ll1)*0.05,ul1+(ul1-ll1)*0.05,ll2-(ul2-ll2)*0.05,ul2+(ul2-ll2)*0.05])
    print('best r2_score=',m_r2[a],', corresponding alpha=', ilist[a])
    print('number of selected features:',num_feature)
    return df, feature[a], score[a], metric[a]

# %%
# kernel='rbf',gamma=1.0
X = cdata_maxabs
y = cog_norm
ll1 = 0.001
ul1 = 0.006
step1 = 6
ll2 = 0.71
ul2 = 0.90
step2 = 20
state = 73
score_min = 10
score_max = 52
result_row, feature, score, metric = elastic_net(X, y, ll1, ul1, step1, ll2, ul2, step2, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=1200, style=ProgressStyle(description_width='initi…
# best r2_score= -0.40210654314658323 , corresponding alpha= (0.004, 0.73)
# number of selected features: 26

# %%
# kernel='rbf',gamma=1.0
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.026674
# True     0.026674  1.000000

# %% [markdown]
# ### pdata

# %%
# kernel='rbf',gamma=0.5, epsilon=0.01, C=1
X = pdata_maxabs
y = cog_norm
ll1 = 0.0085
ul1 = 0.0089
step1 = 5
ll2 = 0.990
ul2 = 0.999
step2 = 10
state = 73
score_min = 10
score_max = 52
result_row, feature, score, metric = elastic_net(X, y, ll1, ul1, step1, ll2, ul2, step2, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=500, style=ProgressStyle(description_width='initia…
# best r2_score= 0.02135443847909162 , corresponding alpha= (0.0085, 0.998)
# number of selected features: 23

# %%
# kernel='rbf',gamma=0.5, epsilon=0.01, C=1
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.302198
# True     0.302198  1.000000

# %% [markdown]
# ## Single kernel RFE

# %%
def svmrfe(X, y, ll, ul, state, score_min, score_max):
    kf = KFold(n_splits=10,shuffle=True,random_state=state)
    score = []
    R2 = []
    MSE = []
    fmap = []
    pbar = tnrange((ul-ll)*10, desc='loop')
    ilist = range(ll,ul)
    for train_index, test_index in kf.split(X):
        mse = []
        r2 = []
        sco = []
        y_train, y_test_raw = y[train_index], y[test_index]
        X_train_tmp, X_test_tmp = X[train_index], X[test_index]
        y_test_raw = list(list(zip(*y_test_raw))[0])
        svr_rfe = SVR(kernel='linear')
        rfe = RFE(estimator=svr_rfe, n_features_to_select=1, step=1)
        rfe.fit(X_train_tmp, y_train)
        importance = np.argsort(rfe.ranking_)
        fmap.append(importance)       
        for i in ilist:
            X_train = X_train_tmp[:,importance[:i]]
            X_test = X_test_tmp[:,importance[:i]]
#             svr = SVR(kernel='linear')
            svr = SVR(kernel='rbf',gamma=0.35, epsilon=0.1, C=1)
#             svr = SVR(kernel='rbf',gamma=1.0, epsilon=0.001)
#             svr = SVR(kernel='rbf',gamma=1.0, epsilon=0.1)
            
            svr.fit(X_train, np.ravel(y_train))
            y_test_pred_raw = svr.predict(X_test)
            y_test_pred = cal_score(y_test_pred_raw,score_max,score_min)
            y_test = cal_score(y_test_raw,score_max,score_min)
            mse.append(mean_squared_error(y_test, y_test_pred))
            r2.append(r2_score(y_test, y_test_pred))
            sco.append((list(y_test_pred), list(y_test)))
            pbar.update(1)
        R2.append(r2)
        score.append(sco)
        MSE.append(mse)
    m_r2 = np.mean(np.array(R2), axis = 0)
    idx = np.argmax(m_r2)
    metric = (np.array(R2)[:,idx], np.array(MSE)[:,idx])
    feature_fd = [list(fmap[i][:ilist[idx]]) for i in range(10)]
    score_pred = [score[i][idx][0] for i in range(10)]
    score_true = [score[i][idx][1] for i in range(10)]
    score_fd = [score_pred, score_true]
    df = {'max_r2': m_r2[idx],'num_features': ilist[idx]}
    pbar.close()
#     plt.figure()
#     plt.plot(ilist,m_r2)
#     plt.xlabel('$alpha$')
#     plt.ylabel('$R^2$')
    print('best r2_score=',m_r2[idx])
    print(m_r2)
    print('number of selected features:',ilist[idx])
    return df, feature_fd, score_fd, metric

# %%
# gamma=1.0, epsilon=0.1
# 62 63 65
X = xdata_maxabs
y = cog_norm
ll = 1
ul = 70
state = 73
score_min = 10
score_max = 52
result, feature, score, metric = svmrfe(X, y, ll, ul, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=690, style=ProgressStyle(description_width='initia…
# best r2_score= 0.10995567734378571
# [-0.05835502 -0.05318047 -0.04784824 -0.03655195 -0.04914828 -0.02225649
#  -0.01650797 -0.00363031 -0.00891612 -0.00930292 -0.04861995 -0.05165063
#  -0.03507124 -0.03048202 -0.03100763 -0.03458105 -0.04302614 -0.02660571
#  -0.03521831 -0.03210627 -0.0150067  -0.01738968 -0.01246694  0.00368813
#  -0.00112059 -0.01070442 -0.02372928 -0.02484533 -0.03254678 -0.04359035
#  -0.03942121 -0.02619073 -0.01590389 -0.01618866 -0.01269879 -0.01093516
#  -0.00040908  0.01148308  0.01627609  0.02826328  0.03235225  0.04023396
#   0.02993998  0.02665549  0.03448395  0.04429628  0.03758331  0.03900992
#   0.03988179  0.0462853   0.04450558  0.05145828  0.05480931  0.0613996
#   0.07254358  0.07701685  0.08362159  0.09136808  0.09134282  0.09567408
#   0.10083309  0.10874429  0.10883555  0.10774436  0.10995568  0.10187729
#   0.10119284  0.10247618  0.10279979]
# number of selected features: 65

# %%
# gamma=1.0, epsilon=0.1
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.398336
# True     0.398336  1.000000

# %%
# gamma=1.0, epsilon=0.001
# 127 128 129 130
X = rdata_maxabs
y = cog_norm
ll = 1
ul = 700
state = 73
score_min = 10
score_max = 52
result, feature, score, metric = svmrfe(X, y, ll, ul, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=6990, style=ProgressStyle(description_width='initi…
# best r2_score= 0.160153282445001
# [-8.89909015e-02 -1.40307862e-01 -2.02747001e-01 -1.61763935e-01
#  -2.18396845e-01 -3.01898106e-01 -3.45135318e-01 -4.48482460e-01
#  -4.58705578e-01 -4.96600731e-01 -5.72861041e-01 -5.83135979e-01
#  -6.54698366e-01 -6.64955771e-01 -6.66855942e-01 -6.40117091e-01
#  -6.30968348e-01 -6.35453768e-01 -6.66730118e-01 -6.92998314e-01
#  -6.81267743e-01 -6.83798560e-01 -6.33109366e-01 -6.10169326e-01
#  -6.34480066e-01 -6.33657816e-01 -6.18901498e-01 -5.66593279e-01
#  -5.78586392e-01 -5.94955714e-01 -5.49679318e-01 -4.63169657e-01
#  -4.42273939e-01 -4.36940314e-01 -3.98045532e-01 -3.34427233e-01
#  -2.97037726e-01 -3.08964175e-01 -2.83053477e-01 -2.57638887e-01
#  -2.46432136e-01 -2.88388102e-01 -2.56298814e-01 -2.11340771e-01
#  -1.82787485e-01 -1.61683745e-01 -1.73421642e-01 -1.52455524e-01
#  -1.67878297e-01 -1.61928911e-01 -1.65482553e-01 -1.66883551e-01
#  -1.48182881e-01 -1.17186167e-01 -1.04410905e-01 -1.00253433e-01
#  -8.40927742e-02 -7.85652925e-02 -6.93577364e-02 -5.43670084e-02
#  -4.67832578e-02 -3.93625018e-02 -4.69412531e-02 -4.03469381e-02
#  -3.44824120e-02 -2.61567803e-02 -2.34386843e-02 -1.59206827e-02
#  -5.76184646e-03  5.78369468e-04  3.94977631e-03  6.57401109e-03
#  -1.63574134e-03  1.10092688e-02  9.06152257e-03  1.72043002e-02
#   2.50585188e-02  3.27835510e-02  4.45232946e-02  5.54930081e-02
#   5.07799265e-02  5.70199577e-02  4.93875881e-02  4.97826869e-02
#   5.97146201e-02  7.01052197e-02  7.00039749e-02  6.97905366e-02
#   6.78151867e-02  7.19126698e-02  8.62274751e-02  8.86845128e-02
#   9.10746958e-02  9.92884017e-02  1.05403015e-01  1.07574143e-01
#   1.12825694e-01  1.18632978e-01  1.21620912e-01  1.24833259e-01
#   1.25158733e-01  1.25587710e-01  1.28483616e-01  1.31595374e-01
#   1.31406332e-01  1.31228469e-01  1.41951964e-01  1.41258441e-01
#   1.42285068e-01  1.42891901e-01  1.44261664e-01  1.46801504e-01
#   1.44652041e-01  1.47393020e-01  1.47050176e-01  1.45755717e-01
#   1.49558064e-01  1.51142060e-01  1.52531716e-01  1.51189512e-01
#   1.52001742e-01  1.51739487e-01  1.52278466e-01  1.54459969e-01
#   1.56550654e-01  1.57558513e-01  1.58481992e-01  1.60153282e-01
#   1.59457518e-01  1.58809655e-01  1.56867596e-01  1.56722198e-01
#   1.54938938e-01  1.55512811e-01  1.56220538e-01  1.55475297e-01
#   1.52764908e-01  1.54753728e-01  1.53893324e-01  1.54071028e-01
#   1.54665017e-01  1.55751572e-01  1.55275211e-01  1.54950033e-01
#   1.54825710e-01  1.52642636e-01  1.51499746e-01  1.50162361e-01
#   1.47825859e-01  1.47439217e-01  1.46615438e-01  1.47674240e-01
#   1.47511689e-01  1.45042048e-01  1.44708136e-01  1.43363533e-01
#   1.44061315e-01  1.44325371e-01  1.44747639e-01  1.44286938e-01
#   1.44103095e-01  1.43311882e-01  1.42459201e-01  1.42173807e-01
#   1.41031868e-01  1.42363878e-01  1.41378055e-01  1.40923059e-01
#   1.40410157e-01  1.40736758e-01  1.40464752e-01  1.39051689e-01
#   1.37867566e-01  1.36898026e-01  1.40151803e-01  1.40636649e-01
#   1.40976829e-01  1.39363488e-01  1.39849186e-01  1.39982828e-01
#   1.38589329e-01  1.38451013e-01  1.37226884e-01  1.34113049e-01
#   1.33371026e-01  1.32228655e-01  1.32801363e-01  1.32386799e-01
#   1.31252311e-01  1.30280940e-01  1.29644723e-01  1.28723486e-01
#   1.27951156e-01  1.27424755e-01  1.26100138e-01  1.24859449e-01
#   1.23991809e-01  1.23258086e-01  1.22624052e-01  1.21624269e-01
#   1.21365434e-01  1.18339507e-01  1.17454454e-01  1.17404546e-01
#   1.17188942e-01  1.16505235e-01  1.15592910e-01  1.15014328e-01
#   1.14183792e-01  1.14257654e-01  1.14432353e-01  1.13779275e-01
#   1.13669918e-01  1.12220942e-01  1.10511477e-01  1.09638388e-01
#   1.09110472e-01  1.08936936e-01  1.08170257e-01  1.07313068e-01
#   1.07383042e-01  1.07400298e-01  1.06543606e-01  1.06037605e-01
#   1.05699150e-01  1.05042061e-01  1.04795654e-01  1.04391815e-01
#   1.03928812e-01  1.02970069e-01  1.02452915e-01  1.01760886e-01
#   1.00558451e-01  9.97935570e-02  9.92396273e-02  9.85828615e-02
#   9.80928505e-02  9.73594053e-02  9.74415115e-02  9.65293800e-02
#   9.63707333e-02  9.49595528e-02  9.41176234e-02  9.35122088e-02
#   9.30052653e-02  9.22817094e-02  9.15804025e-02  9.11089125e-02
#   9.05625897e-02  8.95860448e-02  8.88906927e-02  8.78692297e-02
#   8.69960541e-02  8.69484949e-02  8.68205971e-02  8.57634410e-02
#   8.51813897e-02  8.43199820e-02  8.35500892e-02  8.27525852e-02
#   8.23157779e-02  8.15905365e-02  8.12170529e-02  8.03587691e-02
#   7.97831754e-02  7.92856746e-02  7.88103684e-02  7.83549276e-02
#   7.79414138e-02  7.73444612e-02  7.68954415e-02  7.64195057e-02
#   7.62768398e-02  7.58466365e-02  7.52298409e-02  7.44199051e-02
#   7.43500859e-02  7.41363718e-02  7.36704337e-02  7.31390317e-02
#   7.26728576e-02  7.22345402e-02  7.17267902e-02  7.12946147e-02
#   7.03573866e-02  6.95047671e-02  6.91237796e-02  6.89096950e-02
#   6.82409498e-02  6.79210082e-02  6.77953343e-02  6.73563623e-02
#   6.71692101e-02  6.63848929e-02  6.61903879e-02  6.58165283e-02
#   6.55860132e-02  6.54137683e-02  6.53218113e-02  6.49784672e-02
#   6.42226577e-02  6.37886080e-02  6.34601859e-02  6.28524229e-02
#   6.22960041e-02  6.20201917e-02  6.18243198e-02  6.13596932e-02
#   6.12556865e-02  6.09802800e-02  6.01667998e-02  5.99414048e-02
#   5.93690808e-02  5.89068404e-02  5.86613376e-02  5.84231977e-02
#   5.81968565e-02  5.79147005e-02  5.75050907e-02  5.66435192e-02
#   5.64566609e-02  5.62623287e-02  5.58894104e-02  5.57820735e-02
#   5.52694786e-02  5.49112531e-02  5.44108182e-02  5.39678099e-02
#   5.37032552e-02  5.35282645e-02  5.29887396e-02  5.29311332e-02
#   5.27241893e-02  5.25443003e-02  5.22665928e-02  5.17050843e-02
#   5.12436873e-02  5.06327166e-02  5.03286816e-02  5.01889859e-02
#   5.01293129e-02  4.97927110e-02  4.95952081e-02  4.94227693e-02
#   4.90263878e-02  4.86469562e-02  4.84646484e-02  4.82597770e-02
#   4.80477731e-02  4.74631097e-02  4.73166384e-02  4.70836532e-02
#   4.66818982e-02  4.63776582e-02  4.60611067e-02  4.59377614e-02
#   4.57150565e-02  4.52152048e-02  4.52435426e-02  4.50601874e-02
#   4.46892591e-02  4.45510483e-02  4.42417691e-02  4.38904137e-02
#   4.34789998e-02  4.31689051e-02  4.29449949e-02  4.25165136e-02
#   4.20710868e-02  4.16882091e-02  4.15626839e-02  4.12928743e-02
#   4.10898094e-02  4.07718016e-02  4.04943034e-02  4.03174718e-02
#   3.93773969e-02  3.92526817e-02  3.89056924e-02  3.86288874e-02
#   3.84210818e-02  3.82349426e-02  3.77988500e-02  3.73465513e-02
#   3.70847417e-02  3.69675103e-02  3.66972443e-02  3.64916664e-02
#   3.61322270e-02  3.59901590e-02  3.56147758e-02  3.52808773e-02
#   3.48443404e-02  3.46475517e-02  3.45569673e-02  3.43080168e-02
#   3.40876357e-02  3.39489718e-02  3.38461487e-02  3.36719935e-02
#   3.35586733e-02  3.32967224e-02  3.28937971e-02  3.26476228e-02
#   3.24785405e-02  3.19929604e-02  3.19353810e-02  3.17393094e-02
#   3.13749608e-02  3.11365659e-02  3.09752955e-02  3.07905312e-02
#   3.04623951e-02  3.02885795e-02  3.00258143e-02  2.98914609e-02
#   2.97072376e-02  2.95042859e-02  2.89383930e-02  2.85910250e-02
#   2.84537882e-02  2.78675218e-02  2.76904119e-02  2.76388881e-02
#   2.74946197e-02  2.72219634e-02  2.70608684e-02  2.68763820e-02
#   2.67904359e-02  2.67262877e-02  2.65940570e-02  2.64841330e-02
#   2.63512545e-02  2.61493335e-02  2.59288942e-02  2.57105809e-02
#   2.55326489e-02  2.47535436e-02  2.44838682e-02  2.42714989e-02
#   2.42132502e-02  2.40421087e-02  2.39298035e-02  2.27924673e-02
#   2.26100905e-02  2.25616746e-02  2.23357183e-02  2.22679067e-02
#   2.20730185e-02  2.18779471e-02  2.17433556e-02  2.13303312e-02
#   2.09156335e-02  2.08122407e-02  2.06821380e-02  2.05743319e-02
#   2.04753929e-02  2.03171419e-02  2.01172589e-02  1.98780751e-02
#   1.97244377e-02  1.94674482e-02  1.93658463e-02  1.92840544e-02
#   1.90873482e-02  1.90402204e-02  1.86580263e-02  1.84906856e-02
#   1.80911377e-02  1.79979192e-02  1.78974445e-02  1.73743643e-02
#   1.72689917e-02  1.70830055e-02  1.70182963e-02  1.69331754e-02
#   1.68518203e-02  1.67290815e-02  1.65470448e-02  1.64150193e-02
#   1.63187351e-02  1.61734284e-02  1.60199410e-02  1.58022856e-02
#   1.55609408e-02  1.54655264e-02  1.53365367e-02  1.52646575e-02
#   1.52045574e-02  1.47414977e-02  1.44275774e-02  1.41997282e-02
#   1.35408394e-02  1.32558666e-02  1.32083910e-02  1.30793033e-02
#   1.29692398e-02  1.27983541e-02  1.25973076e-02  1.25664225e-02
#   1.24479790e-02  1.23335706e-02  1.22457782e-02  1.21708636e-02
#   1.21047809e-02  1.18129344e-02  1.16207422e-02  1.14773747e-02
#   1.13409044e-02  1.12855728e-02  1.11991583e-02  1.10977831e-02
#   1.10728756e-02  1.09969056e-02  1.08159617e-02  1.04963677e-02
#   1.03387798e-02  1.02679780e-02  1.00979385e-02  1.00351515e-02
#   9.91925928e-03  9.85917717e-03  9.71355582e-03  9.67200006e-03
#   9.54922793e-03  9.46495580e-03  9.30793114e-03  9.25872027e-03
#   9.20628593e-03  9.14660969e-03  9.09872278e-03  8.94675645e-03
#   8.68364737e-03  8.56504296e-03  8.48303553e-03  8.26352397e-03
#   8.16345536e-03  7.59619689e-03  7.48083682e-03  7.38829324e-03
#   7.28394550e-03  7.21130384e-03  7.01304085e-03  6.91312681e-03
#   6.80312542e-03  6.78158570e-03  6.67005907e-03  6.55585867e-03
#   6.51322902e-03  6.44330945e-03  6.14185626e-03  6.02919632e-03
#   5.96808493e-03  5.89013390e-03  5.81124590e-03  5.68912823e-03
#   5.40695935e-03  5.29692098e-03  5.24659625e-03  5.01684286e-03
#   4.89626143e-03  4.73232455e-03  4.65414496e-03  4.56114863e-03
#   4.46737486e-03  4.24904114e-03  4.20384067e-03  4.01599392e-03
#   3.90678594e-03  3.64408565e-03  3.56317062e-03  3.41517401e-03
#   3.22621208e-03  3.15523551e-03  3.10921546e-03  3.00614481e-03
#   2.86904127e-03  2.73815914e-03  2.60572115e-03  2.57043805e-03
#   2.43477110e-03  2.33951088e-03  2.17937017e-03  2.07568595e-03
#   1.93296700e-03  1.22945288e-03  1.15456994e-03  1.06595962e-03
#   1.00263674e-03  7.58676239e-04  6.94797746e-04  5.92805912e-04
#   5.40783046e-04  4.51760294e-04  4.15542259e-04  1.32852116e-04
#   1.01274698e-04 -1.17104819e-04 -2.52237924e-04 -4.50949843e-04
#  -4.96048232e-04 -5.73914406e-04 -7.29256773e-04 -8.14549216e-04
#  -9.23065799e-04 -9.63978876e-04 -1.05778386e-03 -1.12406483e-03
#  -1.26742956e-03 -1.36091793e-03 -1.39822883e-03 -1.43368689e-03
#  -1.53490023e-03 -1.66015069e-03 -1.70451821e-03 -1.74968162e-03
#  -1.78235593e-03 -1.89634644e-03 -1.92391002e-03 -1.95207119e-03
#  -2.03568357e-03 -2.16689225e-03 -2.36833174e-03 -2.42619545e-03
#  -2.48073807e-03 -2.55657475e-03 -2.62199306e-03 -2.69050091e-03
#  -2.78346778e-03 -2.88074407e-03 -3.34955248e-03 -3.47615436e-03
#  -3.54806052e-03 -3.85393541e-03 -4.03125859e-03 -4.21024389e-03
#  -4.24962689e-03 -4.35577435e-03 -4.37138100e-03 -4.43096447e-03
#  -4.49781170e-03 -4.58732780e-03 -4.63390117e-03 -4.76359961e-03
#  -4.89551568e-03 -4.96506801e-03 -5.20415298e-03 -5.33471906e-03
#  -5.45103180e-03 -5.55381383e-03 -5.75366623e-03 -5.79819614e-03
#  -5.85949026e-03 -5.88554191e-03 -5.92650461e-03 -6.01001848e-03
#  -6.07805228e-03 -6.12395901e-03 -6.19109887e-03 -6.23137322e-03
#  -6.26868085e-03 -6.35134926e-03 -6.52479494e-03 -6.57760865e-03
#  -6.66193858e-03 -6.74315987e-03 -6.77352388e-03 -6.80503452e-03
#  -6.86899512e-03 -6.98061100e-03 -7.12489955e-03 -7.21084687e-03
#  -7.40098591e-03 -7.43931262e-03 -7.47666374e-03 -7.53722819e-03
#  -7.56975055e-03 -7.63922010e-03 -7.68374486e-03 -7.77834441e-03
#  -7.84295348e-03 -7.87273668e-03 -8.02903031e-03 -8.08758931e-03
#  -8.17410149e-03 -8.27930998e-03 -8.42382052e-03 -8.48171797e-03
#  -8.54233546e-03 -8.66044470e-03 -8.68800929e-03 -8.75167182e-03
#  -8.82136871e-03 -8.89354896e-03 -8.99716730e-03 -9.03369292e-03
#  -9.07344121e-03 -9.10774407e-03 -9.18753063e-03]
# number of selected features: 128

# %%
# gamma=1.0, epsilon=0.001
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.516124
# True     0.516124  1.000000

# %%
# gamma=0.35, epsilon=0.1
X = rdata_maxabs
y = cog_norm
ll = 1
ul = 700
state = 73
score_min = 10
score_max = 52
result, feature, score, metric = svmrfe(X, y, ll, ul, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=6990, style=ProgressStyle(description_width='initi…
# best r2_score= 0.04253779375361956
# [-2.90860447e-02 -4.65250101e-02 -8.14195784e-02 -8.07335381e-02
#  -1.14629031e-01 -1.51331039e-01 -1.98207777e-01 -2.13426895e-01
#  -2.37280695e-01 -3.18568616e-01 -3.70439274e-01 -4.13787552e-01
#  -4.24466446e-01 -4.42810028e-01 -4.51830133e-01 -4.14660624e-01
#  -4.44826366e-01 -4.17543584e-01 -4.44451966e-01 -4.27274930e-01
#  -4.32963620e-01 -4.65202102e-01 -4.54410734e-01 -5.09635886e-01
#  -4.84912202e-01 -4.73504216e-01 -4.51825189e-01 -4.42178824e-01
#  -4.39928671e-01 -4.33572463e-01 -4.30339675e-01 -4.03666707e-01
#  -3.87017462e-01 -3.83252373e-01 -3.69448688e-01 -3.21787471e-01
#  -2.83413516e-01 -2.79311290e-01 -2.72204090e-01 -2.82203605e-01
#  -2.79171054e-01 -2.79378698e-01 -2.80469837e-01 -2.71135266e-01
#  -2.52594666e-01 -2.35829904e-01 -2.57146937e-01 -2.36809180e-01
#  -2.57058375e-01 -2.52308252e-01 -2.59954185e-01 -2.68088759e-01
#  -2.51095795e-01 -2.32623834e-01 -2.14682333e-01 -2.13406693e-01
#  -2.02654761e-01 -1.96941904e-01 -1.79854785e-01 -1.80180969e-01
#  -1.72890670e-01 -1.64325475e-01 -1.63880721e-01 -1.65268529e-01
#  -1.62257251e-01 -1.45275190e-01 -1.47802986e-01 -1.41622139e-01
#  -1.30442071e-01 -1.23292419e-01 -1.17430232e-01 -1.18111132e-01
#  -1.20663754e-01 -1.30292497e-01 -1.37177524e-01 -1.33931614e-01
#  -1.37225884e-01 -1.36127518e-01 -1.23706904e-01 -1.07806607e-01
#  -1.08639137e-01 -1.09654602e-01 -1.10703811e-01 -1.09621674e-01
#  -9.86563612e-02 -8.82578198e-02 -9.16522645e-02 -9.47630449e-02
#  -1.00953752e-01 -9.50251731e-02 -9.05949335e-02 -8.86520939e-02
#  -8.44766146e-02 -7.76325546e-02 -7.71055374e-02 -7.77912612e-02
#  -7.12006802e-02 -6.68587649e-02 -5.98192811e-02 -5.76762826e-02
#  -5.82172593e-02 -5.71004270e-02 -5.23351197e-02 -5.27015092e-02
#  -5.25426974e-02 -5.18263702e-02 -3.91152025e-02 -4.23964199e-02
#  -4.06429027e-02 -4.11579596e-02 -4.00539055e-02 -3.24690993e-02
#  -3.15479608e-02 -2.55462918e-02 -2.53663812e-02 -2.68279771e-02
#  -1.93258014e-02 -1.60286686e-02 -1.63175975e-02 -1.53740795e-02
#  -1.22824778e-02 -1.36640705e-02 -1.31262355e-02 -4.86201895e-03
#  -3.21226153e-03 -1.39183743e-04 -1.17423393e-03  1.07425048e-03
#  -1.07888106e-03 -6.77444891e-04 -3.52839100e-03 -2.20169962e-03
#  -4.88329096e-03 -5.28814752e-03 -5.38468965e-03 -7.61146510e-03
#  -7.85522629e-03 -4.99989802e-03 -2.83937057e-03 -1.09085323e-03
#  -2.73243756e-04  2.03337648e-03  4.48215640e-03  5.70428496e-03
#   7.08692243e-03  4.88542549e-03  2.00147804e-03  1.29830985e-03
#  -9.95608998e-04  3.24893959e-04  1.73735811e-05  1.64863429e-03
#   1.39974755e-03  2.52463703e-04  9.32689769e-04  1.22567672e-04
#  -5.49887271e-04  7.59961638e-04  2.20450446e-03  1.61589557e-03
#   1.12821207e-03  1.88732801e-03  2.07083507e-03  2.27650194e-03
#   4.34407872e-03  8.18147808e-03  1.08486201e-02  1.09218386e-02
#   1.12685553e-02  1.37616198e-02  1.54959196e-02  1.49114745e-02
#   1.35307717e-02  1.26009285e-02  1.54935004e-02  1.77859631e-02
#   1.92871238e-02  1.85757668e-02  2.03475274e-02  2.08997826e-02
#   1.98210492e-02  2.25075255e-02  2.16831846e-02  2.20787542e-02
#   2.26349195e-02  2.09199273e-02  2.33494396e-02  2.31162856e-02
#   2.28284901e-02  2.22454874e-02  2.26083917e-02  2.37464958e-02
#   2.55379958e-02  2.62578004e-02  2.68324850e-02  2.80841871e-02
#   2.88532623e-02  2.92403521e-02  3.06660646e-02  3.08722178e-02
#   3.16831626e-02  3.07380016e-02  2.99157382e-02  3.13696912e-02
#   3.10060040e-02  3.25220645e-02  3.41827430e-02  3.47200984e-02
#   3.39613420e-02  3.45437895e-02  3.62269338e-02  3.60474555e-02
#   3.58306850e-02  3.59594544e-02  3.40400784e-02  3.53895150e-02
#   3.49670798e-02  3.64899156e-02  3.57918341e-02  3.52717487e-02
#   3.65186642e-02  3.67715342e-02  3.70311643e-02  3.79950804e-02
#   3.74536780e-02  3.81557087e-02  3.84478856e-02  3.82268921e-02
#   3.90011037e-02  3.79935065e-02  3.89634465e-02  3.88878935e-02
#   3.65657713e-02  3.64256648e-02  3.70647977e-02  3.67678302e-02
#   3.64863819e-02  3.71193766e-02  3.87633981e-02  3.91323661e-02
#   4.00471368e-02  3.94687936e-02  3.91921935e-02  3.83688647e-02
#   3.85358366e-02  4.10664829e-02  4.17151091e-02  4.18059126e-02
#   4.19820477e-02  4.16782136e-02  4.19294817e-02  4.16315410e-02
#   4.18260486e-02  4.23786179e-02  4.25377938e-02  4.17383514e-02
#   4.12375850e-02  4.08893959e-02  4.08787523e-02  4.13826385e-02
#   4.08721500e-02  4.12265644e-02  4.24638643e-02  4.20167696e-02
#   4.21517969e-02  4.24014128e-02  4.16943862e-02  4.16668012e-02
#   4.16451153e-02  4.11261022e-02  4.06205102e-02  4.05834633e-02
#   4.13375885e-02  4.08237020e-02  3.96994646e-02  3.95083187e-02
#   4.04810043e-02  4.07009087e-02  4.03348097e-02  4.01726781e-02
#   4.07858771e-02  4.05738572e-02  3.96115290e-02  3.93035028e-02
#   4.00154756e-02  3.86424681e-02  3.86930098e-02  3.91204145e-02
#   3.76866162e-02  3.69647762e-02  3.75648393e-02  3.70348886e-02
#   3.70470906e-02  3.58360970e-02  3.59801644e-02  3.66874884e-02
#   3.65542387e-02  3.74284481e-02  3.80102050e-02  3.80400766e-02
#   3.78699776e-02  3.78056654e-02  3.77522253e-02  3.74224004e-02
#   3.74405523e-02  3.72768977e-02  3.78674754e-02  3.77253112e-02
#   3.81584057e-02  3.76603193e-02  3.68853095e-02  3.63297063e-02
#   3.59947817e-02  3.56960776e-02  3.58105286e-02  3.61148491e-02
#   3.61328400e-02  3.58092465e-02  3.57811209e-02  3.36468627e-02
#   3.39365337e-02  3.41898821e-02  3.41433250e-02  3.45833017e-02
#   3.38791829e-02  3.40701549e-02  3.41257219e-02  3.38810986e-02
#   3.39399503e-02  3.37739060e-02  3.31029696e-02  3.33430738e-02
#   3.32610964e-02  3.34137682e-02  3.30532707e-02  3.25943663e-02
#   3.27592119e-02  3.23576135e-02  3.28877801e-02  3.28628050e-02
#   3.37325139e-02  3.35011670e-02  3.34560872e-02  3.36161323e-02
#   3.28696379e-02  3.20518614e-02  3.25507105e-02  3.23107777e-02
#   3.18732109e-02  3.17269569e-02  3.16371854e-02  3.14537474e-02
#   3.12255786e-02  3.10585959e-02  3.09162557e-02  3.07866809e-02
#   2.98087187e-02  2.92920707e-02  2.99112639e-02  2.98921749e-02
#   2.97372595e-02  2.94197995e-02  2.92473368e-02  2.91967641e-02
#   2.99065033e-02  2.98577926e-02  2.96795338e-02  2.93032248e-02
#   2.82237459e-02  2.81206042e-02  2.75331947e-02  2.74347799e-02
#   2.75442829e-02  2.73622305e-02  2.74509892e-02  2.70655403e-02
#   2.64929189e-02  2.62020044e-02  2.52225177e-02  2.49331219e-02
#   2.49093928e-02  2.48582999e-02  2.50672233e-02  2.40282310e-02
#   2.43351165e-02  2.46700018e-02  2.46629766e-02  2.48488853e-02
#   2.46757320e-02  2.45108047e-02  2.39532535e-02  2.40133031e-02
#   2.37925870e-02  2.34625412e-02  2.36257524e-02  2.34543830e-02
#   2.34823318e-02  2.38192708e-02  2.44938073e-02  2.40402774e-02
#   2.39715497e-02  2.35602943e-02  2.28573091e-02  2.25323079e-02
#   2.23847578e-02  2.17313020e-02  2.17195180e-02  2.16143319e-02
#   2.17925650e-02  2.11187753e-02  2.11136686e-02  2.09400243e-02
#   2.05125120e-02  2.04237973e-02  2.03472444e-02  2.04303256e-02
#   2.04357454e-02  2.01510207e-02  1.96703597e-02  1.97071040e-02
#   1.96053205e-02  1.86486655e-02  1.83502439e-02  1.88031825e-02
#   1.85267700e-02  1.81454355e-02  1.81897744e-02  1.78775484e-02
#   1.78715226e-02  1.76422602e-02  1.77652301e-02  1.75135170e-02
#   1.75170164e-02  1.72295551e-02  1.68954411e-02  1.70152576e-02
#   1.69746309e-02  1.64755787e-02  1.55855306e-02  1.57726239e-02
#   1.62148217e-02  1.62365551e-02  1.63089179e-02  1.42427352e-02
#   1.45889630e-02  1.47131742e-02  1.44054383e-02  1.41501633e-02
#   1.37597923e-02  1.35827876e-02  1.34326127e-02  1.26982671e-02
#   1.24628892e-02  1.23372848e-02  1.21379402e-02  1.18518027e-02
#   1.17297245e-02  1.19925702e-02  1.13120244e-02  1.09255012e-02
#   1.07106912e-02  1.04910951e-02  1.06363509e-02  1.03071193e-02
#   1.05238585e-02  1.00502930e-02  9.76466371e-03  9.76802601e-03
#   9.47422240e-03  9.38276296e-03  8.78024475e-03  7.54438985e-03
#   7.43507630e-03  7.30604713e-03  7.44910795e-03  7.25804062e-03
#   7.44495670e-03  7.17335867e-03  6.76750598e-03  6.79266428e-03
#   6.90814221e-03  6.76912158e-03  6.66790726e-03  6.41480534e-03
#   6.25485736e-03  6.18462551e-03  6.04825958e-03  5.85593266e-03
#   5.67325564e-03  5.01082320e-03  4.41188927e-03  3.72358355e-03
#   3.42723089e-03  3.02703841e-03  3.01336709e-03  2.76993180e-03
#   2.43419414e-03  2.22118612e-03  1.77788636e-03  1.88488238e-03
#   1.70902579e-03  1.23347523e-03  1.14341802e-03  9.99079132e-04
#   1.21687026e-03  8.20451235e-04  3.90138514e-04  1.22173428e-04
#  -3.63767957e-04 -7.93028048e-04 -7.77840578e-04 -1.07732171e-03
#  -1.25197424e-03 -1.34884278e-03 -1.67127114e-03 -1.50879026e-03
#  -1.74078122e-03 -1.72644103e-03 -2.01441254e-03 -1.91516857e-03
#  -2.00433085e-03 -1.95746186e-03 -1.69694223e-03 -1.62820013e-03
#  -1.91283430e-03 -1.98979859e-03 -2.13808972e-03 -2.21561454e-03
#  -2.36605700e-03 -2.34712104e-03 -2.36345960e-03 -2.31561221e-03
#  -2.45066217e-03 -2.49310777e-03 -2.60044591e-03 -2.92097022e-03
#  -2.81369960e-03 -3.42730843e-03 -3.51989759e-03 -3.53575755e-03
#  -3.99524037e-03 -4.18260683e-03 -4.27869358e-03 -4.43716422e-03
#  -4.53990726e-03 -4.40079715e-03 -4.50867122e-03 -4.73125124e-03
#  -4.87439407e-03 -4.94014800e-03 -5.32678529e-03 -5.42127262e-03
#  -5.52403830e-03 -5.59684774e-03 -5.54997993e-03 -5.63650739e-03
#  -5.77763138e-03 -5.79485060e-03 -5.75917157e-03 -6.22882287e-03
#  -6.43784587e-03 -6.39713142e-03 -6.71764927e-03 -6.84702512e-03
#  -6.80847701e-03 -6.85564194e-03 -6.76926469e-03 -6.90282429e-03
#  -6.88270908e-03 -7.12114075e-03 -6.99017539e-03 -7.14770258e-03
#  -7.48446650e-03 -7.51851166e-03 -7.50039712e-03 -7.57203284e-03
#  -7.99969181e-03 -8.15259467e-03 -8.17788629e-03 -8.21964502e-03
#  -8.31196817e-03 -8.33846281e-03 -8.42712599e-03 -8.61880508e-03
#  -8.75431947e-03 -9.90016747e-03 -1.00540385e-02 -1.02839381e-02
#  -1.03275339e-02 -1.07625176e-02 -1.09599405e-02 -1.09482575e-02
#  -1.10307954e-02 -1.13408917e-02 -1.15415834e-02 -1.18492711e-02
#  -1.19078026e-02 -1.22895617e-02 -1.24534274e-02 -1.26532670e-02
#  -1.28043127e-02 -1.30225720e-02 -1.32163644e-02 -1.32752195e-02
#  -1.33630540e-02 -1.33274986e-02 -1.35493864e-02 -1.36674035e-02
#  -1.39701419e-02 -1.40631496e-02 -1.40731885e-02 -1.41403023e-02
#  -1.40279332e-02 -1.41504589e-02 -1.42068793e-02 -1.42467199e-02
#  -1.43089964e-02 -1.43945835e-02 -1.45504335e-02 -1.46866208e-02
#  -1.47491831e-02 -1.48065249e-02 -1.50258113e-02 -1.49937030e-02
#  -1.51257064e-02 -1.51186897e-02 -1.51415172e-02 -1.53325727e-02
#  -1.55669020e-02 -1.58115803e-02 -1.61493535e-02 -1.65587509e-02
#  -1.68352920e-02 -1.70295790e-02 -1.73222480e-02 -1.76617611e-02
#  -1.76718236e-02 -1.76334524e-02 -1.75291228e-02 -1.76313062e-02
#  -1.77755184e-02 -1.78561098e-02 -1.78329232e-02 -1.80888380e-02
#  -1.82118315e-02 -1.82729549e-02 -1.85531489e-02 -1.88523478e-02
#  -1.89774677e-02 -1.89439483e-02 -1.94584777e-02 -1.94839919e-02
#  -1.95864094e-02 -1.95987755e-02 -1.97105587e-02 -2.00683758e-02
#  -2.01998040e-02 -2.02645910e-02 -2.03119558e-02 -2.03635946e-02
#  -2.04633484e-02 -2.06407853e-02 -2.08875238e-02 -2.10461158e-02
#  -2.11731060e-02 -2.12431416e-02 -2.12717915e-02 -2.12756036e-02
#  -2.13910764e-02 -2.18387162e-02 -2.20732172e-02 -2.22105441e-02
#  -2.23561183e-02 -2.24775097e-02 -2.26135284e-02 -2.25455163e-02
#  -2.26903121e-02 -2.27700291e-02 -2.27764527e-02 -2.27399857e-02
#  -2.30584288e-02 -2.30787999e-02 -2.31378250e-02 -2.31652644e-02
#  -2.33898487e-02 -2.35961448e-02 -2.37575294e-02 -2.38299882e-02
#  -2.38867530e-02 -2.40376817e-02 -2.40684389e-02 -2.42492790e-02
#  -2.43447121e-02 -2.44230858e-02 -2.44847140e-02 -2.45501691e-02
#  -2.45912836e-02 -2.46635081e-02 -2.48213472e-02]
# number of selected features: 255

# %%
# gamma=0.35, epsilon=0.1
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.474089
# True     0.474089  1.000000

# %%
# gamma=0.4, epsilon=0.1
X = rdata_maxabs
y = cog_norm
ll = 1
ul = 700
state = 73
score_min = 10
score_max = 52
result, feature, score, metric = svmrfe(X, y, ll, ul, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=6990, style=ProgressStyle(description_width='initi…
# best r2_score= 0.04069694996176405
# [-2.91499215e-02 -4.59381980e-02 -8.39375243e-02 -8.70390468e-02
#  -1.23575647e-01 -1.64962068e-01 -2.14557671e-01 -2.33145268e-01
#  -2.55891671e-01 -3.46205518e-01 -3.94227927e-01 -4.22292431e-01
#  -4.32084229e-01 -4.65930000e-01 -4.62673601e-01 -4.25903198e-01
#  -4.54749110e-01 -4.26685231e-01 -4.54756762e-01 -4.32977253e-01
#  -4.39238590e-01 -4.75771246e-01 -4.69025987e-01 -5.10364734e-01
#  -4.81665664e-01 -4.68793760e-01 -4.47274164e-01 -4.32459234e-01
#  -4.35282952e-01 -4.26308284e-01 -4.21507606e-01 -3.98793927e-01
#  -3.78375941e-01 -3.67652023e-01 -3.51703255e-01 -3.04857448e-01
#  -2.66013600e-01 -2.62512458e-01 -2.54375036e-01 -2.62460388e-01
#  -2.61624571e-01 -2.61896703e-01 -2.62321764e-01 -2.53360917e-01
#  -2.36812336e-01 -2.22049727e-01 -2.43097680e-01 -2.22706589e-01
#  -2.40667200e-01 -2.35439895e-01 -2.42886934e-01 -2.49928261e-01
#  -2.34222343e-01 -2.14596281e-01 -1.99097681e-01 -1.97176441e-01
#  -1.87502589e-01 -1.82942123e-01 -1.65604429e-01 -1.66921104e-01
#  -1.59966227e-01 -1.50948611e-01 -1.50571358e-01 -1.52335686e-01
#  -1.49920583e-01 -1.32984356e-01 -1.34920635e-01 -1.29240109e-01
#  -1.17347300e-01 -1.09887330e-01 -1.04694848e-01 -1.05239385e-01
#  -1.08683879e-01 -1.17436035e-01 -1.24030608e-01 -1.21044133e-01
#  -1.22818463e-01 -1.22213226e-01 -1.10574304e-01 -9.56489773e-02
#  -9.61968684e-02 -9.66679181e-02 -9.71887169e-02 -9.59976176e-02
#  -8.59527865e-02 -7.65311430e-02 -7.92658376e-02 -8.22583200e-02
#  -8.84019418e-02 -8.29487640e-02 -7.79989862e-02 -7.59576671e-02
#  -7.16114010e-02 -6.50171828e-02 -6.48859588e-02 -6.45223457e-02
#  -5.87309996e-02 -5.44501465e-02 -4.74886278e-02 -4.54639857e-02
#  -4.59072465e-02 -4.45876801e-02 -4.06514544e-02 -4.15680801e-02
#  -4.08053401e-02 -4.03471449e-02 -2.82610652e-02 -3.14418525e-02
#  -2.98802473e-02 -3.06950915e-02 -2.90535070e-02 -2.23958320e-02
#  -2.11475689e-02 -1.53973510e-02 -1.52971347e-02 -1.68208111e-02
#  -9.33821095e-03 -6.17192615e-03 -6.39552541e-03 -5.90474955e-03
#  -3.14372808e-03 -4.04132875e-03 -3.15573756e-03  3.99665592e-03
#   5.92669885e-03  8.45153219e-03  7.74336512e-03  9.54926043e-03
#   7.56293963e-03  7.98982617e-03  5.42996046e-03  6.86635499e-03
#   3.92828066e-03  3.70034277e-03  3.69499533e-03  2.01506331e-03
#   1.59869940e-03  4.68938809e-03  6.31217038e-03  7.67060543e-03
#   9.42396883e-03  1.09030091e-02  1.38756326e-02  1.49044623e-02
#   1.64507686e-02  1.46704792e-02  1.23750459e-02  1.12639060e-02
#   8.63192170e-03  9.82529480e-03  9.47390665e-03  1.09984367e-02
#   1.05972915e-02  9.14902097e-03  9.47051441e-03  8.82051298e-03
#   8.23629900e-03  9.56767648e-03  1.11340045e-02  1.02930323e-02
#   1.00838359e-02  1.10247149e-02  1.13852536e-02  1.13861303e-02
#   1.29824154e-02  1.61779611e-02  1.87113303e-02  1.89535156e-02
#   1.89836920e-02  2.14129983e-02  2.29212380e-02  2.23793583e-02
#   2.07889564e-02  2.00128321e-02  2.30532234e-02  2.51134077e-02
#   2.61770245e-02  2.56938253e-02  2.74343536e-02  2.75269699e-02
#   2.63625274e-02  2.90185785e-02  2.81160901e-02  2.82730444e-02
#   2.88235408e-02  2.74983159e-02  2.99821865e-02  2.96564797e-02
#   2.91144556e-02  2.85205955e-02  2.85833984e-02  2.99212836e-02
#   3.14437096e-02  3.17300110e-02  3.22734705e-02  3.30546509e-02
#   3.37911016e-02  3.38921585e-02  3.50008500e-02  3.48228955e-02
#   3.57418445e-02  3.42565590e-02  3.36443638e-02  3.50195618e-02
#   3.47497000e-02  3.59812211e-02  3.72665321e-02  3.78944866e-02
#   3.70500085e-02  3.75627364e-02  3.89396059e-02  3.86794683e-02
#   3.86061992e-02  3.88009097e-02  3.68608751e-02  3.79126649e-02
#   3.76341288e-02  3.89617975e-02  3.79801863e-02  3.74733509e-02
#   3.85456055e-02  3.87207812e-02  3.87378642e-02  3.95003426e-02
#   3.90193413e-02  3.94562194e-02  3.99948897e-02  3.96507523e-02
#   4.02915337e-02  3.93915226e-02  4.02861892e-02  4.01653550e-02
#   3.77472775e-02  3.74983002e-02  3.78673581e-02  3.75518781e-02
#   3.72205965e-02  3.77595780e-02  3.90039368e-02  3.90727198e-02
#   4.01366539e-02  3.92393219e-02  3.85530141e-02  3.80820593e-02
#   3.83608808e-02  4.03849396e-02  4.06954595e-02  4.06969500e-02
#   4.06138803e-02  4.02181658e-02  4.04195102e-02  3.99162367e-02
#   3.99182689e-02  4.03267040e-02  4.04196377e-02  3.93607557e-02
#   3.88799791e-02  3.84399503e-02  3.82030271e-02  3.85999596e-02
#   3.81452496e-02  3.80624959e-02  3.91350120e-02  3.84402630e-02
#   3.85861451e-02  3.86938560e-02  3.79570085e-02  3.80507658e-02
#   3.78380287e-02  3.72168089e-02  3.67724025e-02  3.67195703e-02
#   3.75404033e-02  3.67626838e-02  3.57627716e-02  3.54967996e-02
#   3.62230914e-02  3.64024767e-02  3.61458059e-02  3.61789339e-02
#   3.63578337e-02  3.59897232e-02  3.50284089e-02  3.50071141e-02
#   3.53895897e-02  3.41848827e-02  3.42572638e-02  3.43524590e-02
#   3.30257926e-02  3.22461340e-02  3.28739965e-02  3.24186418e-02
#   3.25093682e-02  3.11472205e-02  3.12912401e-02  3.18510967e-02
#   3.17714429e-02  3.24345062e-02  3.28905584e-02  3.28272662e-02
#   3.24656584e-02  3.23204154e-02  3.21949389e-02  3.18845228e-02
#   3.16452909e-02  3.16994154e-02  3.19011106e-02  3.19319675e-02
#   3.21496646e-02  3.17620388e-02  3.07088194e-02  3.01892154e-02
#   2.99776054e-02  2.95282502e-02  2.96534320e-02  2.98629248e-02
#   2.97014070e-02  2.94762462e-02  2.94225311e-02  2.72042006e-02
#   2.74309854e-02  2.76398714e-02  2.74814261e-02  2.78038288e-02
#   2.72122505e-02  2.71070868e-02  2.71031182e-02  2.70052368e-02
#   2.69913506e-02  2.68648075e-02  2.61416431e-02  2.63002866e-02
#   2.61471383e-02  2.62979337e-02  2.60709604e-02  2.54021612e-02
#   2.53018265e-02  2.50045561e-02  2.51913011e-02  2.52386047e-02
#   2.59208203e-02  2.55353153e-02  2.54274404e-02  2.55208329e-02
#   2.48790629e-02  2.39054821e-02  2.42784500e-02  2.41998400e-02
#   2.36347799e-02  2.32530515e-02  2.31456932e-02  2.30789312e-02
#   2.28282469e-02  2.24211392e-02  2.23133436e-02  2.22385869e-02
#   2.13242244e-02  2.08335809e-02  2.13307955e-02  2.12597519e-02
#   2.08478698e-02  2.04688468e-02  2.02992199e-02  2.03522312e-02
#   2.08101274e-02  2.07303881e-02  2.04513606e-02  2.01198150e-02
#   1.89580266e-02  1.86914315e-02  1.81952288e-02  1.80826315e-02
#   1.80600239e-02  1.78429567e-02  1.77720321e-02  1.74953795e-02
#   1.69026855e-02  1.66191930e-02  1.57523500e-02  1.53689132e-02
#   1.52996630e-02  1.51265793e-02  1.51622726e-02  1.41758670e-02
#   1.44834282e-02  1.47223734e-02  1.46096515e-02  1.48177105e-02
#   1.45825770e-02  1.44107986e-02  1.37799609e-02  1.36942561e-02
#   1.36274116e-02  1.32938878e-02  1.33396728e-02  1.31704370e-02
#   1.29506191e-02  1.31950086e-02  1.35528538e-02  1.31736433e-02
#   1.30089553e-02  1.26345361e-02  1.20007199e-02  1.15741891e-02
#   1.13325018e-02  1.08083837e-02  1.06493175e-02  1.04896584e-02
#   1.04021824e-02  9.90847210e-03  9.87665211e-03  9.64937158e-03
#   9.32515197e-03  9.09888511e-03  9.01633437e-03  9.08104158e-03
#   8.88770664e-03  8.59195237e-03  8.08559600e-03  8.08761167e-03
#   7.92140437e-03  6.96318483e-03  6.69287913e-03  7.09724698e-03
#   6.75807775e-03  6.28903880e-03  6.31063284e-03  5.94839718e-03
#   5.90808092e-03  5.71087701e-03  5.66929288e-03  5.54580709e-03
#   5.47064100e-03  5.13160354e-03  4.90172743e-03  4.87579595e-03
#   4.71278506e-03  4.18624447e-03  3.42103421e-03  3.49727285e-03
#   3.77573408e-03  3.71249500e-03  3.79445415e-03  1.83782498e-03
#   2.08386114e-03  2.07510144e-03  1.73983130e-03  1.57696137e-03
#   1.21712126e-03  9.23399993e-04  7.63047856e-04  1.80789596e-04
#  -1.28634748e-04 -2.26153188e-04 -4.87706277e-04 -6.58838093e-04
#  -7.64766921e-04 -6.22408006e-04 -1.42016805e-03 -1.82981044e-03
#  -2.04357928e-03 -2.28322325e-03 -2.33077511e-03 -2.61439130e-03
#  -2.45943170e-03 -2.94739067e-03 -3.08848124e-03 -3.18571142e-03
#  -3.59797387e-03 -3.67642548e-03 -4.27519323e-03 -5.54870773e-03
#  -5.57253304e-03 -5.74761207e-03 -5.81042625e-03 -5.84982595e-03
#  -5.78735210e-03 -6.10796931e-03 -6.37434758e-03 -6.36137501e-03
#  -6.32704449e-03 -6.52029279e-03 -6.76291582e-03 -6.79876524e-03
#  -6.99573566e-03 -7.04279215e-03 -7.18579878e-03 -7.42564837e-03
#  -7.65313072e-03 -8.30000461e-03 -8.86831893e-03 -9.53236062e-03
#  -9.91932348e-03 -1.04156559e-02 -1.04906941e-02 -1.06723136e-02
#  -1.09399165e-02 -1.11662447e-02 -1.15775176e-02 -1.14916041e-02
#  -1.16757997e-02 -1.20991440e-02 -1.22018480e-02 -1.24073974e-02
#  -1.22335945e-02 -1.26433543e-02 -1.29174670e-02 -1.32843742e-02
#  -1.37214706e-02 -1.40782358e-02 -1.40909895e-02 -1.44051316e-02
#  -1.45797766e-02 -1.46117042e-02 -1.48967731e-02 -1.48145087e-02
#  -1.50783680e-02 -1.50931155e-02 -1.54329248e-02 -1.53467512e-02
#  -1.54238763e-02 -1.54280990e-02 -1.53033134e-02 -1.52721019e-02
#  -1.54660898e-02 -1.55539701e-02 -1.57689298e-02 -1.59286731e-02
#  -1.60064760e-02 -1.59844253e-02 -1.59935664e-02 -1.60599010e-02
#  -1.62472477e-02 -1.63282619e-02 -1.63870137e-02 -1.66793100e-02
#  -1.66876096e-02 -1.73311209e-02 -1.74237549e-02 -1.75255875e-02
#  -1.78923577e-02 -1.80444107e-02 -1.82275939e-02 -1.83686412e-02
#  -1.84858297e-02 -1.84425681e-02 -1.85163951e-02 -1.87635246e-02
#  -1.88806760e-02 -1.90107441e-02 -1.93711249e-02 -1.95284327e-02
#  -1.95525186e-02 -1.96687220e-02 -1.96880983e-02 -1.97879497e-02
#  -1.99274330e-02 -1.99243542e-02 -1.99401502e-02 -2.04629737e-02
#  -2.06974327e-02 -2.06414336e-02 -2.09338506e-02 -2.10582100e-02
#  -2.10859700e-02 -2.12364623e-02 -2.11747262e-02 -2.12802623e-02
#  -2.13045970e-02 -2.15141908e-02 -2.15012143e-02 -2.17150422e-02
#  -2.18818869e-02 -2.19663133e-02 -2.19888030e-02 -2.20834213e-02
#  -2.24251244e-02 -2.26024309e-02 -2.26385338e-02 -2.26684683e-02
#  -2.27722582e-02 -2.28496124e-02 -2.29929829e-02 -2.31962451e-02
#  -2.33306562e-02 -2.43894649e-02 -2.45287258e-02 -2.47386361e-02
#  -2.48071655e-02 -2.51863926e-02 -2.53795520e-02 -2.54453635e-02
#  -2.55269196e-02 -2.57897912e-02 -2.59556152e-02 -2.63412668e-02
#  -2.63602867e-02 -2.67144701e-02 -2.69117126e-02 -2.71188028e-02
#  -2.72120877e-02 -2.74286422e-02 -2.76016267e-02 -2.76322453e-02
#  -2.77743293e-02 -2.77737241e-02 -2.79768690e-02 -2.81345554e-02
#  -2.84186721e-02 -2.85766264e-02 -2.85628702e-02 -2.86522589e-02
#  -2.85416311e-02 -2.86769688e-02 -2.87342722e-02 -2.88030355e-02
#  -2.88769075e-02 -2.90216634e-02 -2.91247923e-02 -2.92173394e-02
#  -2.93061883e-02 -2.93202954e-02 -2.96014835e-02 -2.96404753e-02
#  -2.97170659e-02 -2.97947240e-02 -2.98489798e-02 -2.99893112e-02
#  -3.01760979e-02 -3.04312131e-02 -3.07589311e-02 -3.11055561e-02
#  -3.14008021e-02 -3.16038136e-02 -3.19223827e-02 -3.22002667e-02
#  -3.21956087e-02 -3.21690586e-02 -3.20942702e-02 -3.22217901e-02
#  -3.23424045e-02 -3.24991212e-02 -3.25168645e-02 -3.27024120e-02
#  -3.28929935e-02 -3.29477510e-02 -3.32259261e-02 -3.34699597e-02
#  -3.36148792e-02 -3.36122707e-02 -3.40831085e-02 -3.41362717e-02
#  -3.42157966e-02 -3.42134106e-02 -3.42936436e-02 -3.46533558e-02
#  -3.47950314e-02 -3.48511801e-02 -3.49699574e-02 -3.50344453e-02
#  -3.51168049e-02 -3.52804833e-02 -3.55740767e-02 -3.56996522e-02
#  -3.58080579e-02 -3.59073781e-02 -3.59480857e-02 -3.60208521e-02
#  -3.61363537e-02 -3.64324513e-02 -3.66856880e-02 -3.68351575e-02
#  -3.69903989e-02 -3.70870623e-02 -3.72258125e-02 -3.71962525e-02
#  -3.72811286e-02 -3.73861306e-02 -3.74246996e-02 -3.74782647e-02
#  -3.76879591e-02 -3.77238858e-02 -3.77879143e-02 -3.78641776e-02
#  -3.80612136e-02 -3.82071511e-02 -3.83636439e-02 -3.84254470e-02
#  -3.85131516e-02 -3.87093108e-02 -3.87276761e-02 -3.88654325e-02
#  -3.90249080e-02 -3.90783870e-02 -3.91369313e-02 -3.91925047e-02
#  -3.92434148e-02 -3.93015254e-02 -3.94178619e-02]
# number of selected features: 248

# %%
# gamma=0.5, epsilon=0.1
from tkinter import _flatten
pred = list(_flatten(score[0]))
true = list(_flatten(score[1]))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.479733
# True     0.479733  1.000000

# %% [markdown]
# ## Multi kernel

# %%
def single_lasso(x_train_tmp, y_train, ll, ul, step):
    fea_idx = []
    alpha = []
    ilist = np.linspace(ll,ul,step)
    for i in ilist:
        reg = Lasso(alpha=i)
        reg.fit(x_train_tmp, np.ravel(y_train))
        fea_idx.append([i for i,x in enumerate(reg.coef_) if x>0])
        alpha.append(i)
    return fea_idx, alpha

def single_elastic_net(x_train_tmp, y_train, ll1, ul1, step1, ll2, ul2, step2):
    fea_idx = []
    alpha = []
    inp = [list(create_alpha(ll1,ul1,step1)), list(np.linspace(ll2,ul2,step2))]
    g = [i for i in itertools.product(*inp)]
    for k in range(len(g)):
        reg = ElasticNet(random_state=state,alpha=g[k][0],l1_ratio=g[k][1])
        reg.fit(x_train_tmp, np.ravel(y_train))
        fea_idx.append([i for i,x in enumerate(reg.coef_) if x>0])
        alpha.append(g[k])
    return fea_idx, alpha

def single_rfe(x, y, ln, un):
    svr_rfe = SVR(kernel='linear')
    rfe = RFE(estimator=svr_rfe, n_features_to_select=1, step=1)
    rfe.fit(x, y)
    importance = np.argsort(rfe.ranking_)
    fea_idx = []
    alpha = []
    for i in range(ln,un):
        fea_idx.append(importance[:i])
        alpha.append(i)
    return fea_idx, alpha

def select_features(X, y_train, train_index, l):
    rf, ra = single_rfe(X[0][train_index], y_train, l[0][0], l[0][1])
    cf, ca = single_lasso(X[1][train_index], y_train, l[1][0], l[1][1], l[1][2])
    pf, pa = single_lasso(X[2][train_index], y_train, l[2][0], l[2][1], l[2][2])
    xf, xa = single_rfe(X[3][train_index], y_train, l[3][0],l[3][1])
    return ra, rf, ca, cf, pa, pf, xa, xf

def gram_lin(X1, X2, w):
    s= 0
    for i in range(4):
        X1[i]=np.array(X1[i])
        X2[i]=np.array(X2[i])
        s += w[i]* linear_kernel(X1[i], X2[i])
    return s
def gram_rbf(X1, X2, params, w):
    s= 0
    for i in range(4):
        X1[i]=np.array(X1[i]) 
        X2[i]=np.array(X2[i])
        s += w[i]* rbf_kernel(X1[i], X2[i], params[i])
    return s

# %%
def multi(X, y, L, params, state, score_min, score_max):
    kf = KFold(n_splits=10,shuffle=True,random_state=state)
    multi_feature = []
    multi_score = []
    multi_r2 = []
    multi_mse = []
    w_grid = [list(np.linspace(0.0,1.0,11,dtype = np.float32))]
    W_grid = w_grid * len(L)
    W= [i for i in itertools.product(*W_grid) if np.sum(i)==1.0]
    W = [(0.2, 0.0, 0.1, 0.7)]
    pbar = tnrange(len(W), desc='loop')
    for t, w in enumerate(W):
        feature = []
        metric = []
        R2 = []
        MSE = []
        score = []
        for train_index, test_index in kf.split(y):
            y_test_raw = np.ravel(y[test_index])
            y_train = np.ravel(y[train_index])
            svr = SVR(kernel='precomputed',epsilon=0.01)
            ra, rf, ca, cf, pa, pf, xa, xf = select_features(X, y_train, train_index, L)
            mse = []
            r2 = []
            alpha = []
            fea = {}
            sco = {}
            for r in range(len(ra)):
                for c in range(len(ca)):
                    for p in range(len(pa)):
                        for x in range(len(xa)):
                            key = (ra[r],ca[c],xa[x],pa[p])
                            fea[key] = [list(rf[r]),cf[c],list(xf[x]),pf[p]]
                            X_train = [X[0][train_index][:,rf[r]], 
                                       X[1][train_index][:,cf[c]], 
                                        X[2][train_index][:,pf[p]], 
                                       X[3][train_index][:,xf[x]]]
                            X_test = [X[0][test_index][:,rf[r]], 
                                      X[1][test_index][:,cf[c]], 
                                        X[2][test_index][:,pf[p]], 
                                      X[3][test_index][:,xf[x]]]
#                             kernel_train = gram_lin(X_train, X_train, w)
                            kernel_train = gram_rbf(X_train, X_train, params, w)

                            svr.fit(kernel_train, np.ravel(y_train))
                            y_test_pred_raw = svr.predict(gram_rbf(X_test, X_train, params, w))
                            y_test_pred = cal_score(y_test_pred_raw,score_max,score_min)
                            y_test = cal_score(y_test_raw,score_max,score_min)
                            mse.append(mean_squared_error(y_test, y_test_pred))
                            r2.append(r2_score(y_test, y_test_pred))
                            alpha.append(key)
                            sco[key] = (y_test_pred,y_test)
            R2.append(r2)
            MSE.append(mse)
            feature.append(fea)
            score.append(sco)
        avr_r2 = np.mean(np.array(R2),axis=0)
        avr_mse = np.mean(np.array(MSE),axis=0)
        idx = np.argmax(avr_r2)
        metric = (np.array(MSE)[:,idx], np.array(R2)[:,idx])
        multi_r2.append(avr_r2[idx])
        multi_mse.append(avr_mse[idx])
        pbar.update(1)
        print('No.', t+1,'. best r2_score=',avr_r2[idx],', corresponding alpha=', alpha[idx])
    pbar.close()
    multi_idx = np.argmax(multi_r2)
    print('End of grid search. best r2_score=',multi_r2[multi_idx])
    return feature, result, score, (alpha,avr_r2)              #not useful unless you control the weights

# %%
l_r = [255,256]
l_c = [0.00688,0.00690,1]
l_p = [0.00866,0.00890,1]
l_x = [65,66]
L = [l_r,l_c,l_p,l_x]
params = [0.35,1.0,0.5,1.0]
state = 73
score_min = 10
score_max = 52
feature, result, score, alpha = multi(data_maxabs, cog_norm, L, params, state, score_min, score_max)
# Out:
# HBox(children=(IntProgress(value=0, description='loop', max=1, style=ProgressStyle(description_width='initial'…
# No. 1 . best r2_score= 0.24876656078529807 , corresponding alpha= (255, 0.00688, 65, 0.00866)
#
# End of grid search. best r2_score= 0.24876656078529807

# %%
pred=[]
true=[]
for sc in score:
    pair = list(sc.values())[0]
    pred.append(list(pair[0]))
    true.append(list(pair[1]))

# %%
from tkinter import _flatten
pred = list(_flatten(pred))
true = list(_flatten(true))
df_score = pd.DataFrame({'Predict':pred,'True':true})
df_score.corr()
# Out:
#           Predict      True
# Predict  1.000000  0.539279
# True     0.539279  1.000000

# %%
plt.figure()
plt.plot([0,49],[0,49])
plt.scatter(pred,true,color='#97CBFF',marker='v')
plt.xlabel('$R^2\;Plot$')
# pd.DataFrame({'mse@best-alpha':score[0],'r2@best-alpha':score[1]})
# pd.DataFrame({'pred@best-alpha-fold':result[0],'true@best-alpha-fold':result[1]})
# Out:
# Text(0.5, 0, '$R^2\\;Plot$')
